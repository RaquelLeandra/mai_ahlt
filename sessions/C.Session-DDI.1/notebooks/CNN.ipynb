# %%
from tqdm import tqdm
from os import listdir
import pandas as pd
from xml.dom.minidom import parse
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix


stopwords = set(stopwords.words('english'))

output_path_name = "task9.2_raquel_6.txt"

output_path = "evaluations/" + output_path_name
results_path = output_path.replace('.txt', '_All_scores.log')
datadir = '../../data/Test-DDI/DrugBank'
training_data = '/home/raquel/Documents/mai/ahlt/data/Train/All'
train_df_path = '/home/raquel/Documents/mai/ahlt/data/DF/train.csv'

# %%
import numpy as np

from keras.layers import Dense, Input, Flatten, Reshape, concatenate, Dropout
from keras.layers import Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Embedding
from keras.layers import LSTM, Bidirectional
from keras.models import Model
from keras import optimizers
from keras import regularizers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

import sys
from text_processing_util import TextProcessing
# Out:
# Using TensorFlow backend.

# %%
train_df = pd.read_csv('saved_train_nice.csv', index_col=0)

sentences = train_df.sentence_text.values
y_train = train_df['relation_type'].values

y_binary = ['none' if i == 'none' else 'interaction 'for i in y_train]


sentences_train, sentences_test, y_train, y_test = train_test_split(sentences, y_binary, test_size=0.25, random_state=1000,stratify=y_binary)


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences_train)
word_index = tokenizer.word_index


X_train = tokenizer.texts_to_sequences(sentences_train)
X_test = tokenizer.texts_to_sequences(sentences_test)


vocab_size = len(tokenizer.word_index) + 1  # Adding 1 because of reserved 0 index
max_s = [len(x) for x in X_train]
maxlen = np.max(max_s)

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
from gensim.models import KeyedVectors

# %%
fname='/home/raquel/Documents/mai/ahlt/data/GoogleNews-vectors-negative300.bin'
model = KeyedVectors.load_word2vec_format(fname, binary=True)

# %%
len(model.wv.vocab)
# Out:
# /home/raquel/Documents/mai/ahlt/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# 3000000

# %%
 model.vector_size
# Out:
# 300

# %%
def get_weight_matrix(w2v,vocab):
    # define weight matrix dimensions with all 0
    vocab_size = len(vocab) + 1
    weight_matrix = np.zeros((vocab_size, w2v.vector_size))
    # step vocab, store vectors using the Tokenizer's integer mapping
    for word, i in vocab.items():
        try:
            weight_matrix[i] = w2v[word]
        except:
            print(word)
    return weight_matrix

embedding_vectors = get_weight_matrix(model, tokenizer.word_index)
# emb_layer = Embedding(vocab_size, output_dim=w2v.vector_size, weights=[embedding_vectors], input_length=FIXED_LENGTH, trainable=False)
# Out:
# and
# of
# a
# to
# rsb
# lsb
# clofibrate
# tolbutamide
# mefenamic
# methyldopa
# aminosalicylic
# diflunisal
# sulfinpyrazone
# chlorpropamide
# bromelains
# ethacrynic
# oxyphenbutazone
# fenoprofen
# diazoxide
# nalidixic
# chymotrypsin
# cinchophen
# dextrothyroxine
# oxolinic
# phenyramidol
# pyrazolones
# triclofos
# delavirdine
# dicumarol
# viracept
# felbamate
# felbatol
# crixivan
# tegretol
# prelone
# invirase
# fortovase
# norvir
# agenerase
# kaletra
# theodur
# rifadin
# astramorph
# kadian
# sporanox
# nizoral
# trileptal
# sandimmune
# grispeg
# neoral
# atromids
# cypa
# ethionamide
# iodinecontaining
# agonistantagonist
# nanm
# acetophenazine
# cephalothin
# tcas
# magnesiumaluminumcontaining
# teniposide
# levodromoran
# nacmc
# underdosage
# oxymetholone
# maois
# precedex
# acebutolol
# multipledose
# antiacid
# indanavir
# phenobarbitol
# ritanovir
# cnsdepressant
# eldepryl
# starlix
# calcitriolergocalcitriol
# dofetilide
# magnesiumcontaining
# permitil
# orthonovum
# phenformin
# tenormin
# duragesic
# oxygenin
# betaagonists
# sprycel
# betaendorphin
# sectral
# qtc
# gleevec
# phenytoinphenobarbital
# cefamandole
# thioxanthenes
# tailflick
# qtcprolonging
# ltryptophan
# inderal
# lopressor
# cancidas
# dezocine
# inspra
# antidepressantsantianxiety
# drugdrug
# dirithromycin
# extraneal
# tromethamine
# fosinoprilat
# crohns
# winstrol
# ssri
# octapeptide
# ampicillinflucoxacillin
# hydrodolasetron
# betaadrenergicblocking
# antiinflammatories
# anadrol
# tripelennamine
# damphetamine
# choplike
# mlh
# dexbrompheniramine
# benzylpenicillin
# cationcontaining
# calciumblocking
# cmccys
# anavar
# phenylalkylamine
# enzymeinducing
# mofetil
# gkgmin
# arecoline
# eproxindine
# pyreneperone
# antidepressantswhen
# anabolin
# benzothiazepine
# sulfapyridine
# hctz
# hblocking
# hydoxide
# orphenadrine
# cefotetan
# tubocurarine
# ergottype
# methysergide
# deltasone
# orasone
# bloodglucoselowering
# tricor
# warfarintype
# secobarbital
# selfadministration
# estazolam
# pyrilamine
# phenyltoloxamine
# methdilazine
# andtolbutamide
# cefmenoxime
# cefoperazone
# latamoxef
# egf
# mgkgday
# apokyn
# dpenicillamine
# ergotaminecontaining
# difluoropropanol
# pediapred
# metamizol
# omegaconotoxin
# ntype
# omegaagatoxin
# ptype
# chromaffin
# brevibloc
# bentiromide
# lotensin
# serotoninergic
# metaclopramide
# antiulcer
# prinivil
# dynacirc
# hypokalemic
# ergonovine
# lowdose
# medrol
# singledose
# estrogenprogesterone
# almotriptan
# anestheticssedativeshypnoticsopioids
# septra
# azulfidine
# myopathyrhabdomyolysis
# bishydroxycoumarin
# trichlorfon
# pargyline
# carboxymethylcellulosecysteine
# avonex
# hydrochloroquine
# acth
# betablocking
# tambocor
# uricosuric
# adrenergicblocking
# swarfarin
# nafcillin
# sulfamethoxazoletrimethoprim
# sulfisoxazole
# gantrisin
# meclofenamate
# aceiarb
# bombesin
# nuromax
# alphablockers
# hividassociated
# alfenta
# nmethylthiotetrazole
# methylthiadiazole
# antinociceptive
# stadol
# pegasys
# isoniazide
# netilmicin
# brovana
# norpace
# druglaboratory
# zebeta
# postmyocardial
# ephesus
# eprosartan
# hypoprothrombinemia
# potassiumcontaining
# difluoroacetone
# rwarfarin
# potassiumdepleting
# vistide
# tysabri
# betablocker
# kaolinpectin
# gabitril
# veratrum
# coumaphos
# phenprocoumon
# betaa
# bblocking
# ceruleinan
# cholecystokininof
# chewabledispersible
# cnsdepressive
# feso
# cgs
# gkg
# levodopadopa
# antiparkinsonian
# antimuscarinics
# transcriptase
# busulfex
# nalfon
# dosedependent
# gallamine
# decamethonium
# lglutamine
# kytril
# methenamine
# shortacting
# cmin
# cefditoren
# antiarrhythrnics
# propatenone
# chlorpropamides
# hydantoin
# fatsoluble
# inomax
# azlocillin
# prednisoneprednisolone
# betagan
# pharmacoktnetics
# nph
# methylphenyltetrahydropyridine
# betanaltrexol
# fluothane
# maxipime
# immobilised
# amiloridetriamterene
# ldlc
# theophyllinequinolone
# ghml
# antinaturetic
# proteinbinding
# diphenylhydantoin
# cotreatment
# oxipurinol
# anileridine
# myobloc
# xigris
# geocillin
# carbenicillin
# indanyl
# lmethionine
# broadspectrum
# rtpa
# hyperprolactinaemia
# peganone
# pectoris
# asv
# ethinamate
# casodex
# systemicallyadministered
# antiglaucoma
# coadministering
# tolazamide
# mevacor
# noninsulin
# betalactam
# antiasthma
# desbutyl
# trisilicate
# indanedione
# anisindione
# nacetyltransferase
# clcr
# comedications
# doxorubicinol
# heparininduced
# metabotropic
# mglur
# thyroidal
# nonfailing
# cikg
# novoseven
# nnrti
# suprax
# vasoconstricting
# sequestrants
# proarrhythmic
# pyrocarbonate
# alkalinize
# microgkg
# betaadrenoceptor
# vaiproic
# norgestrel
# atropinetype
# slowrelease
# lipidlowering
# idoxuridine
# desethylamiodarone
# hydroxyestazolam
# mugml
# mna
# recommendedlevetiracetam
# hydroflumethiazide
# tiazac
# piiia
# somatremsomatropin
# tbg
# azopt
# brinzolamide
# femara
# gliftor
# slowchannel
# intravascularly
# cordarone
# hypotensioncimetidine
# altretamines
# diamox
# sympatholytic
# trisphosphate
# patchclamp
# wholecell
# fura
# microfluorometry
# oxytocics
# dinoprost
# hypertonus
# thiazidetype
# velcade
# ergamisol
# fdf
# inapsine
# cephaloridine
# mumolliter
# preanesthetic
# skeletalmuscle
# areaunderthecurve
# ethopropazine
# mephenytoin
# mesantoin
# dmpge
# cecectomized
# nafazodone
# depakene
# ratelimiting
# didanosineplacebo
# minipill
# ironfortified
# eulexin
# toradolivim
# tbars
# warfarinvitamin
# immunodepressant
# monooxygenase
# nilutamide
# fenofibric
# nondepolarising
# chemotherapyinduced
# qhs
# robinul
# nitrosourea
# iodinate
# methoxycoronaridine
# antiaddictive
# nitroferricyanide
# microgramml
# difluoropropanolintoxicated
# falpha
# hplc
# alternateday
# betaseron
# hypoparathyroid
# antimycotics
# succinylcholineinduced
# ethanolysis
# odesacetyl
# endotoxininduced
# casecontrol
# vasotec
# twiceaday
# calciumentry
# uroxatral
# antihiv
# saquinavirritonavir
# nydrazid
# vaprisol
# reninangiotensin
# captoprildigoxin
# dopamineinduced
# thrombocyte
# tdm
# mtcmdp
# digoxinplacebo
# erectionsupporting
# arabinoside
# bitolterol
# isrecommended
# hydroxymethylglutaryl
# cypb
# cyclopentolate
# gmday
# ergomar
# triacetyloleandomycin
# enrol
# antipeptic
# ratedecreasing
# calan
# tilade
# heartratelowering
# nadololporpranololtimolol
# achloralose
# tcaplasma
# noncomparative
# threohydrobupropion
# desyrel
# betalactamtype
# ulcerans
# ndiethylmtoluamide
# insulininduced
# baraclude
# depressasnts
# aceinhibitorsreports
# rocaltrol
# twolever
# signalledunsignalled
# differentialreinforcementoflowrates
# drl
# porpranolol
# emtriva
# pth
# penicillintype
# isuprel
# intersubject
# sirolimusdiltiazem
# ethotoin
# causeandeffect
# atacand
# revlimid
# acidbase
# boric
# serotoninreceptors
# treatmentnaive
# cytochalasin
# lymecycline
# dalametenkephalinamide
# antinonciceptive
# intracisternal
# oxc
# hydroxydesloratadine
# atrovent
# colazal
# refludan
# aptt
# sulphenazole
# dietaryobese
# watermiscible
# crossreactivity
# nsaidsa
# colestipolconcomitant
# thienobenzodiazepine
# norfluoxetine
# chirocaine
# coadminister
# histidines
# lithiuma
# angiotensln
# penthrane
# methoxyflurane
# dyphylline
# carinii
# cmv
# benzoxazinorifamycin
# prothrombinproconvertin
# umolt
# nmethyllevallorphan
# bindingbased
# mmolday
# phenobarbitone
# oilconcomitant
# earlyphase
# clonidineit
# iop
# hyperuricemic
# dfur
# fbal
# wyethayerst
# orlistatorlistat
# kcl
# mmoll
# nonsteroial
# tripleimmunosuppression
# barpress
# supersensitivity
# cholestyramineconcomitant
# cefizox
# polyene
# sixhealthymale
# tranexamic
# aminocaproic
# stereoisomer
# thyroxinebinding
# cypermethrininduced
# alphaadrenergic
# factrel
# aspirinmediated
# arachidonate
# collagenstimulated
# signalling
# aucs
# anticryptosporidial
# antabuselike
# cocaineinduced
# sisomer
# diphenidol
# microgramskg
# cpk
# triazo
# radicalmediated
# cimetldine
# opioiddependent
# monohydroxy
# differin
# tegison
# biorad
# platelia
# eia
# piperacillintazobactam
# mgweek
# escherichia
# etodolactreated
# delayedrelease
# twosecond
# treatmentemergent
# microgkgday
# acidcatalyzed
# cefotan
# leukopenic
# kdependent
# impinger
# ntg
# cimetidines
# esmolol
# wthionamide
# trecatorsc
# txb
# etopophos
# antibioticsbroadspectrum
# ptxinduced
# delavirdinebased
# phenurone
# phenacemide
# rauwolfia
# tnfablocking
# remicade
# cremophor
# toxilab
# thinlayer
# emitdau
# radioenzymatic
# dodecyl
# dihydroxycholecalciferol
# druglaboratorytest
# dactinomycin
# csf
# methyltetrahydrofolate
# aspirinnonsteroidal
# enzymeinducer
# dsmivdiagnosed
# tykerb
# pgp
# tcametabolism
# bombesinenhanced
# wistar
# galangin
# dihydroxyflavone
# erythrohydrobupropion
# dosedependently
# mazindol
# beadministered
# becausedecreases
# plasmaconcentrations
# clonidines
# anxietydepressive
# pmediated
# oxaloacetate
# interpatient
# hydantoins
# cypamediated
# tcatreatment
# necrolysis
# labelling
# drugadded
# acetaminophenphenobarbital
# caffeinerelated
# jaffe
# propranolols
# plasmalevel
# coadminstered
# etofibrate
# postheparin
# lipolytic
# htriglyceride
# valproates
# mtcoinjection
# falsepositive
# benedicts
# fehlings
# clinitest
# clinistix
# cype
# ellence
# copd
# adultonset
# progestational
# carbacholstimulated
# kappaselective
# trisenox
# hydroxybenzodiazepine
# coumaphoskgday
# tumour
# disulfiramethanol
# doubleblind
# dostinex
# dantagonists
# timedependent
# unitsday
# cefoxitin
# jaff
# anticholinergiccontaining
# noradrenalineprecontracted
# furadantin
# methotrexaterelated
# gramkilogramday
# oxytoca
# anitagonism
# bactercidal
# onestage
# gemzar
# halflives
# norbuprenorphine
# hydralazines
# amidetype
# gentamycinkg
# bwt
# dantrium
# clotibrate
# dayold
# piie
# cardiotrast
# copaxone
# cevimeline
# lasma
# somatrem
# kemstrotm
# hydroxyatomoxetine
# hyperreninemia
# amiodaronetreated
# quinamm
# depletors
# rifamate
# colestid
# cholino
# adrenoreceptors
# angiotensins
# drugssubstances
# comedication
# deoxycytidine
# nimotop
# levofloxacinoxycodone
# campstimulated
# digoxinamiodarone
# sertindole
# campath
# bicnu
# chromatographicmass
# opioidinduced
# acetohydroxamic
# lithostat
# ndodecyl
# didrex
# embryocidal
# concentrationdependent
# preconstricted
# dihydrotachysterol
# dfcr
# nonsignificantly
# aminoglycosidic
# enkephalinergic
# mptpinduced
# morphineexperienced
# erpf
# dimethylprostaglandin
# dmpgeinduced
# mgl
# preexist
# niddm
# kemstro
# hypokinesia
# supplementsantacids
# sulfacetamide
# mentax
# butenafine
# vecuroniuminduced
# humorsol
# hivinfected
# volumedepleted
# caverject
# zinecard
# hyperlocomotion
# mayuse
# paraxanthine
# hemabate
# fludara
# persantine
# exposureresponse
# incombination
# respectto
# mtcmethylene
# diphosphonate
# mdpgentamicin
# ocupress
# betablockade
# inspmediated
# penciclovir
# nonbenzodiazepine
# triazolopyridazines
# vitamindmediated
# estrogendependent
# soriatane
# tetracyclic
# maprotiline
# rebif
# qrs
# hypervitaminosis
# progestincontaining
# anticholinergictype
# anionicbinding
# reexacerbation
# hepatoxicity
# ethynyl
# limitedthereforeconsideration
# nonionized
# nonenzyme
# trecator
# antituberculous
# dimenhydrinate
# smx
# ermbt
# vasospastic
# ssritcainteractions
# alphablocker
# guafacine
# cardioselective
# disulfiramlike
# atac
# pentobarbitalinduced
# longsedation
# rbc
# phenothiazinerelated
# hypotensite
# bileacidsequestering
# pharmacokinetits
# palytoxininduced
# guineapig
# deferens
# placeboday
# plaquenil
# ganglionicblocking
# hormonalmethods
# usedas
# inwomen
# nevirapinemay
# thesemedications
# transdimethylhydroxyphenyl
# piperidine
# accumbal
# quinidex
# oxymetazoline
# selfinjection
# coumaphoskg
# antiprothrombinemic
# glutathionestransferase
# intrathecally
# crescentic
# iga
# oculobulbar
# stevensjohnson
# placebotreated
# sulfoxone
# diasone
# plenaxis
# levorphanol
# plicamycin
# mithracin
# cbz
# glucocorticoidinduced
# sodation

# %%
def kimCNN(EMBEDDING_DIM, MAX_SEQUENCE_LENGTH, MAX_NB_WORDS, word_index, labels_index):
    """
    Convolution neural network model for sentence classification.
    Parameters
    ----------
    EMBEDDING_DIM: Dimension of the embedding space.
    MAX_SEQUENCE_LENGTH: Maximum length of the sentence.
    MAX_NB_WORDS: Maximum number of words in the vocabulary.
    embeddings_index: A dict containing words and their embeddings.
    word_index: A dict containing words and their indices.
    labels_index: A dict containing the labels and their indices.
    Returns
    -------
    compiled keras model
    """
    print('Preparing embedding matrix.')
    num_words = min(MAX_NB_WORDS, len(word_index))
#     embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
#     for word, i in word_index.items():
#         if i >= MAX_NB_WORDS:
#             continue
#         embedding_vector = embeddings_index.get(word)
#         if embedding_vector is not None:
#             # words not found in embedding index will be all-zeros.
#             embedding_matrix[i] = embedding_vector
    MAX_SEQUENCE_LENGTH = maxlen
    num_words = vocab_size
    embedding_layer = Embedding(input_dim=num_words,
                                output_dim=EMBEDDING_DIM,
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=True)


    print('Training model.')

    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedded_sequences = embedding_layer(sequence_input)
    print(embedded_sequences.shape)


    # add first conv filter
    embedded_sequences = Reshape((MAX_SEQUENCE_LENGTH, EMBEDDING_DIM, 1))(embedded_sequences)
    x = Conv2D(100, (5, EMBEDDING_DIM), activation='relu')(embedded_sequences)
    x = MaxPooling2D((MAX_SEQUENCE_LENGTH - 5 + 1, 1))(x)


    # add second conv filter.
    y = Conv2D(100, (4, EMBEDDING_DIM), activation='relu')(embedded_sequences)
    y = MaxPooling2D((MAX_SEQUENCE_LENGTH - 4 + 1, 1))(y)


    # add third conv filter.
    z = Conv2D(100, (3, EMBEDDING_DIM), activation='relu')(embedded_sequences)
    z = MaxPooling2D((MAX_SEQUENCE_LENGTH - 3 + 1, 1))(z)


    # concate the conv layers
    alpha = concatenate([x,y,z])

    # flatted the pooled features.
    alpha = Flatten()(alpha)

    # dropout
    alpha = Dropout(0.5)(alpha)

    # predictions
    preds = Dense(1, activation='softmax')(alpha)

    # build model
    model = Model(sequence_input, preds)
    adadelta = optimizers.Adadelta()
        
    model.compile(loss='softmax',
                  optimizer=adadelta,
                  metrics=['acc'])
    model.summary()

    return model

word_embedding_size = 200
word_pos = 20
labels_index = dict((x,i) for i,x in enumerate(set(y_train)))
model = kimCNN(EMBEDDING_DIM=word_embedding_size, MAX_SEQUENCE_LENGTH=word_pos, MAX_NB_WORDS=len(word_index), word_index=word_index, labels_index=labels_index)
# Out:
# Preparing embedding matrix.
# Training model.
# (?, 97, 200)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 97)           0
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 97, 200)      989400      input_15[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 97, 200, 1)   0           embedding_15[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 93, 1, 100)   100100      reshape_12[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 94, 1, 100)   80100       reshape_12[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 95, 1, 100)   60100       reshape_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 1, 1, 100)    0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 1, 1, 100)    0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 1, 1, 100)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 1, 1, 300)    0           max_pooling2d_31[0][0]
#                                                                  max_pooling2d_32[0][0]
#                                                                  max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 300)          0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 300)          0           flatten_10[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            301         dropout_10[0][0]
# ==================================================================================================
# Total params: 1,230,001
# Trainable params: 1,230,001
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train)
y_test_encoded = encoder.fit_transform(y_test)
model.fit(X_train, y_train_encoded,
                epochs=50,
                verbose=True,
                validation_data=(X_test, y_test_encoded),
                batch_size=100)
# Out:
# Train on 20843 samples, validate on 6948 samples
# Epoch 1/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 2/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 3/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 4/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 5/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 6/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 7/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 8/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 9/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 10/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 11/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 12/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 13/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 14/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 15/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 16/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 17/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 18/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 19/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 20/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 21/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 22/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 23/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 24/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 25/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 26/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 27/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 28/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 29/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 30/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 31/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 32/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 33/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 34/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 35/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 36/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 37/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 38/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 39/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 40/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 41/50
# 20843/20843 [==============================] - 22s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 42/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 43/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 44/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 45/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 46/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 47/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 48/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 49/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 50/50
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554

# %%
y_pred = model.predict(X_test)
y_class = y_pred > 0.5
y_class = y_class.astype(int)
y_labels = [encoder.classes_[l] for l in y_class]
print(f1_score(y_test, y_labels, average=None))
print(precision_score(y_test, y_labels, average="macro"))
print(recall_score(y_test, y_labels, average="macro"))
# Out:
# [0.         0.92203863]
# 0.4276770293609672
# 0.5
# /home/raquel/Documents/mai/ahlt/venv/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/raquel/Documents/mai/ahlt/venv/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
def classify_keras(model):
    from sklearn.preprocessing import LabelEncoder
    encoder = LabelEncoder()
    y_train_encoded = encoder.fit_transform(y_train)
    y_test_encoded = encoder.fit_transform(y_test)
    model.fit(X_train, y_train_encoded,
                    epochs=30,
                    verbose=True,
                    validation_data=(X_test, y_test_encoded),
                    batch_size=100)
    y_pred = model.predict(X_test)
    y_class = y_pred > 0.5
    y_class = y_class.astype(int)
    y_labels = [encoder.classes_[l] for l in y_class]
    print(f1_score(y_test, y_labels, average=None))
    print(precision_score(y_test, y_labels, average="macro"))
    print(recall_score(y_test, y_labels, average="macro"))

classify_keras(model)
# Out:
# Train on 20843 samples, validate on 6948 samples
# Epoch 1/2
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# Epoch 2/2
# 20843/20843 [==============================] - 23s 1ms/step - loss: 2.3061 - acc: 0.8553 - val_loss: 2.3060 - val_acc: 0.8554
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-ba47b132fe58> in <module>
#      18     print(recall_score(y_test, y_labels, average="macro"))
#      19
# ---> 20 classify_keras(model)
#
# <ipython-input-89-ba47b132fe58> in classify_keras(model)
#      14     y_class = y_class.astype(int)
#      15     y_labels = [encoder.classes_[l] for l in y_class]
# ---> 16     print(f1_score(y_test, y_labels, average=None))
#      17     print(precision_score(y_test, y_labels, average="macro"))
#      18     print(recall_score(y_test, y_labels, average="macro"))
#
# NameError: name 'f1_score' is not defined
